# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json
import numpy as np

# %% [markdown]
# ## Marcas productos

# %%
#('h4', class_= 'product-manufacturer')

# %%
for a in range(2,8):
    print  (f"https://www.primor.eu/66-dermocosmetica?p={a}")
# Out:
# https://www.primor.eu/66-dermocosmetica?p=2
# https://www.primor.eu/66-dermocosmetica?p=3
# https://www.primor.eu/66-dermocosmetica?p=4
# https://www.primor.eu/66-dermocosmetica?p=5
# https://www.primor.eu/66-dermocosmetica?p=6
# https://www.primor.eu/66-dermocosmetica?p=7

# %% [markdown]
# ### Página 1

# %%
url = 'https://www.primor.eu/66-dermocosmetica'

# %%
response = requests.get(url).text
beautiful = BeautifulSoup(response,'html.parser')
soup = BeautifulSoup(response,)
marcas = soup.find_all('h4',class_ = 'product-manufacturer')
marcas = [elemento.text for elemento in marcas]
marcas
# Out:
# ['  Deiters ',
#  '  Sesderma ',
#  '  Sesderma ',
#  '  Sesderma ',
#  '  Sesderma ',
#  '  Klorane ',
#  '  Klorane ',
#  '  Avene ',
#  '  Ducray ',
#  '  Ducray ',
#  '  Ducray ',
#  '  Ducray ',
#  '  Ducray ',
#  '  Blistex ',
#  '  Blistex ',
#  '  Bio-Oil ',
#  '  Eucerin ',
#  '  Avene ',
#  '  Sesderma ',
#  '  Beauty Drops ',
#  '  Belcils ',
#  '  Belcils ',
#  '  Sesderma ',
#  '  Sesderma ']

# %%
response = requests.get(url).text
beautiful = BeautifulSoup(response,'html.parser')
soup = BeautifulSoup(response,)
productos = soup.find_all('h5',class_ = 'product-name')
productos = [elemento.text for elemento in productos]
productos
# Out:
# ['  FisioCannabis Crema en Gel Alivio Muscular... ',
#  '  Serenity Bruma Rostro y Almohada ',
#  '  Serenity Sérum Liposomal Noche... ',
#  '  Serenity Mascarilla Facial Nocturna... ',
#  '  Serenity Crema de Noche Antienvejecimiento ',
#  '  Gel Crema Hidratante con Agua de Aciano ',
#  '  Bruma Corporal Hidratante de Peonía ',
#  '  Cicalfate Gel para Cicatrices ',
#  '  Set Keracnyl Sérum + Gel Limpiador ',
#  '  Dexeryl Crema Barrera Aislante ',
#  '  Dermalibour + Crema Reparadora ',
#  '  Set Keracnyl PP Crema + Gel Limpiador ',
#  '  Set Keracnyl Control + Gel Limpiador ',
#  '  Lip Infusion Hydration SPF15 Bálsamo Labial ',
#  '  Lip Infusion Nourish SPF15 Bálsamo Labial ',
#  '  Gel para Piel Seca ',
#  '  DermatoClean Hyaluron Espuma Micelar ',
#  '  Desodorante Roll On 24h Piel Sensible ',
#  '  Oceanskin Crema Facial Nutritiva ',
#  '  Vitamina C al 20% + Ácido Hialurónico ',
#  '  Pack Cejas Perfectas ',
#  '  Máscara Sublime ',
#  '  Juveneses Sebum Regulador ',
#  '  Hidraloe Contorno de Ojos ']

# %%
response = requests.get(url).text
beautiful = BeautifulSoup(response,'html.parser')
soup = BeautifulSoup(response,)
precio_productos = soup.find_all('span', class_='price product-price pull-left')
precio = [elemento.text for elemento in precio_productos]
precio
# Out:
# ['    10,95 €  ',
#  '    21,50 €  ',
#  '    34,99 €  ',
#  '    25,99 €  ',
#  '    29,99 €  ',
#  '    21,99 €  ',
#  '    11,75 €  ',
#  '    10,99 €  ',
#  '    25,50 €  ',
#  '    10,50 €  ',
#  '    4,99 €  ',
#  '    20,99 €  ',
#  '    20,99 €  ',
#  '    1,99 €  ',
#  '    1,99 €  ',
#  '  Desde   9,95 €  ',
#  '    10,99 €  ',
#  '    7,95 €  ',
#  '    28,75 €  ',
#  '    7,95 €  ',
#  '    15,99 €  ',
#  '    14,99 €  ',
#  '    28,75 €  ',
#  '    13,99 €  ']

# %%
page1 = {'Marca': marcas,
            'Nombre' : productos,
            'Precio': precio}
page1 = pd.DataFrame(page1, columns = ['Marca', 'Nombre', 'Precio'])
page1
# Out:
#               Marca                                            Nombre  \
# 0          Deiters     FisioCannabis Crema en Gel Alivio Muscular...
# 1         Sesderma                  Serenity Bruma Rostro y Almohada
# 2         Sesderma                 Serenity Sérum Liposomal Noche...
# 3         Sesderma            Serenity Mascarilla Facial Nocturna...
# 4         Sesderma        Serenity Crema de Noche Antienvejecimiento
# 5          Klorane           Gel Crema Hidratante con Agua de Aciano
# 6          Klorane               Bruma Corporal Hidratante de Peonía
# 7            Avene                     Cicalfate Gel para Cicatrices
# 8           Ducray                Set Keracnyl Sérum + Gel Limpiador
# 9           Ducray                    Dexeryl Crema Barrera Aislante
# 10          Ducray                    Dermalibour + Crema Reparadora
# 11          Ducray             Set Keracnyl PP Crema + Gel Limpiador
# 12          Ducray              Set Keracnyl Control + Gel Limpiador
# 13         Blistex       Lip Infusion Hydration SPF15 Bálsamo Labial
# 14         Blistex         Lip Infusion Nourish SPF15 Bálsamo Labial
# 15         Bio-Oil                                Gel para Piel Seca
# 16         Eucerin              DermatoClean Hyaluron Espuma Micelar
# 17           Avene             Desodorante Roll On 24h Piel Sensible
# 18        Sesderma                  Oceanskin Crema Facial Nutritiva
# 19    Beauty Drops             Vitamina C al 20% + Ácido Hialurónico
# 20         Belcils                              Pack Cejas Perfectas
# 21         Belcils                                   Máscara Sublime
# 22        Sesderma                         Juveneses Sebum Regulador
# 23        Sesderma                         Hidraloe Contorno de Ojos
#
#                 Precio
# 0            10,95 €
# 1            21,50 €
# 2            34,99 €
# 3            25,99 €
# 4            29,99 €
# 5            21,99 €
# 6            11,75 €
# 7            10,99 €
# 8            25,50 €
# 9            10,50 €
# 10            4,99 €
# 11           20,99 €
# 12           20,99 €
# 13            1,99 €
# 14            1,99 €
# 15    Desde   9,95 €
# 16           10,99 €
# 17            7,95 €
# 18           28,75 €
# 19            7,95 €
# 20           15,99 €
# 21           14,99 €
# 22           28,75 €
# 23           13,99 €

# %% [markdown]
# ### Página 2

# %%
url = 'https://www.primor.eu/66-dermocosmetica?p=2'

# %%
response = requests.get(url).text
beautiful = BeautifulSoup(response,'html.parser')
soup = BeautifulSoup(response,)
marcas = soup.find_all('h4',class_ = 'product-manufacturer')
marcas2 = [elemento.text for elemento in marcas]
marcas2
# Out:
# ['  Avene ',
#  '  Avene ',
#  '  Somatoline ',
#  '  Somatoline ',
#  '  Somatoline ',
#  '  Somatoline ',
#  '  Bioderma ',
#  '  Vichy ',
#  '  Weleda ',
#  '  Abbott ',
#  '  NeoStrata ',
#  '  NeoStrata ',
#  '  NeoStrata ',
#  '  Urgo ',
#  '  Lullage ',
#  '  Lullage ',
#  '  Nuxe ',
#  '  Bioderma ',
#  '  Bioderma ',
#  '  Bioderma ',
#  '  Bioderma ',
#  '  Bioderma ',
#  '  Nuxe ',
#  '  Nuxe ']

# %%
response = requests.get(url).text
beautiful = BeautifulSoup(response,'html.parser')
soup = BeautifulSoup(response,)
productos = soup.find_all('h5',class_ = 'product-name')
productos2 = [elemento.text for elemento in productos]
productos2
# Out:
# ['  Cleanance Women Cuidado Facial Nocturno... ',
#  '  Cleanance Women Sérum Corrector ',
#  '  Hombre Abdominales Top Definition ',
#  '  Reductor 7 Noches Natural ',
#  '  Hombre Cintura y Abdomen Intensivo ',
#  '  Anticelulítico Gel Crioactivo ',
#  '  Photerpes Stick Labial Solar SPF50+ ',
#  '  Minéral 89 Mascarilla Fortificante de... ',
#  '  Gel de Baño Tonificante de Romero ',
#  '  Genove Gel Dermatológico Nutritivo e... ',
#  '  Skin Active Intensive Eye Therapy ',
#  '  Espuma Facial Exfoliante ',
#  '  Skin Active Cellular Sérum Reafirmante ',
#  '  Crema Cicatrices ',
#  '  RougeXpert Fluido 360º Tratamiento Intensivo ',
#  '  RougeXpert Spray Calmante Instantáneo ',
#  '  Aceite Hidratante Huile Prodigieuse Or ',
#  '  Sensibio Tolerance+ Hipersensibilidad Cutánea ',
#  '  Sebium Gel Moussant Limpiador Purificante ',
#  '  Sensibio Forte Crema Calmante ',
#  '  Sébium Agua Micelar Piel Acnéica ',
#  '  Pigmentbio Crema Regeneradora Antimanchas ',
#  '  Nuxe Body Gel de Ducha Fundente ',
#  '  Nuxe Body Agua Relajante Perfumada ']

# %%
response = requests.get(url).text
beautiful = BeautifulSoup(response,'html.parser')
soup = BeautifulSoup(response,)
precio_productos = soup.find_all('span', class_='price product-price pull-left')
precio2 = [elemento.text for elemento in precio_productos]
precio2
# Out:
# ['    22,50 €  ',
#  '    22,50 €  ',
#  '    49,99 €  ',
#  '    39,99 €  ',
#  '    42,99 €  ',
#  '    32,75 €  ',
#  '    11,99 €  ',
#  '    4,95 €  ',
#  '    15,99 €  ',
#  '    4,95 €  ',
#  '    44,99 €  ',
#  '    31,90 €  ',
#  '    53,50 €  ',
#  '    12,99 €  ',
#  '    27,50 €  ',
#  '    11,75 €  ',
#  '    19,99 €  ',
#  '    18,99 €  ',
#  '    8,95 €  ',
#  '    17,99 €  ',
#  '    12,99 €  ',
#  '    21,50 €  ',
#  '    7,95 €  ',
#  '    26,50 €  ']

# %%
page2 = {'Marca': marcas2,
            'Nombre' : productos2,
            'Precio': precio2}
page2 = pd.DataFrame(page2, columns = ['Marca', 'Nombre', 'Precio'])
page2
# Out:
#             Marca                                            Nombre  \
# 0          Avene        Cleanance Women Cuidado Facial Nocturno...
# 1          Avene                   Cleanance Women Sérum Corrector
# 2     Somatoline                 Hombre Abdominales Top Definition
# 3     Somatoline                         Reductor 7 Noches Natural
# 4     Somatoline                Hombre Cintura y Abdomen Intensivo
# 5     Somatoline                     Anticelulítico Gel Crioactivo
# 6       Bioderma               Photerpes Stick Labial Solar SPF50+
# 7          Vichy          Minéral 89 Mascarilla Fortificante de...
# 8         Weleda                 Gel de Baño Tonificante de Romero
# 9         Abbott           Genove Gel Dermatológico Nutritivo e...
# 10     NeoStrata                 Skin Active Intensive Eye Therapy
# 11     NeoStrata                          Espuma Facial Exfoliante
# 12     NeoStrata            Skin Active Cellular Sérum Reafirmante
# 13          Urgo                                  Crema Cicatrices
# 14       Lullage      RougeXpert Fluido 360º Tratamiento Intensivo
# 15       Lullage             RougeXpert Spray Calmante Instantáneo
# 16          Nuxe            Aceite Hidratante Huile Prodigieuse Or
# 17      Bioderma     Sensibio Tolerance+ Hipersensibilidad Cutánea
# 18      Bioderma         Sebium Gel Moussant Limpiador Purificante
# 19      Bioderma                     Sensibio Forte Crema Calmante
# 20      Bioderma                  Sébium Agua Micelar Piel Acnéica
# 21      Bioderma         Pigmentbio Crema Regeneradora Antimanchas
# 22          Nuxe                   Nuxe Body Gel de Ducha Fundente
# 23          Nuxe                Nuxe Body Agua Relajante Perfumada
#
#            Precio
# 0       22,50 €
# 1       22,50 €
# 2       49,99 €
# 3       39,99 €
# 4       42,99 €
# 5       32,75 €
# 6       11,99 €
# 7        4,95 €
# 8       15,99 €
# 9        4,95 €
# 10      44,99 €
# 11      31,90 €
# 12      53,50 €
# 13      12,99 €
# 14      27,50 €
# 15      11,75 €
# 16      19,99 €
# 17      18,99 €
# 18       8,95 €
# 19      17,99 €
# 20      12,99 €
# 21      21,50 €
# 22       7,95 €
# 23      26,50 €

# %% [markdown]
# ### Página3

# %%
url = 'https://www.primor.eu/66-dermocosmetica?p=3'

# %%
response = requests.get(url).text
beautiful = BeautifulSoup(response,'html.parser')
soup = BeautifulSoup(response,)
marcas = soup.find_all('h4',class_ = 'product-manufacturer')
marcas3 = [elemento.text for elemento in marcas]
marcas3
# Out:
# ['  Nuxe ',
#  '  Nuxe ',
#  '  Nuxe ',
#  '  Nuxe ',
#  '  Bioderma ',
#  '  Bioderma ',
#  '  Bioderma ',
#  '  Bioderma ',
#  '  Nuxe ',
#  '  Nuxe ',
#  '  Nuxe ',
#  '  Nuxe ',
#  '  Sesderma ',
#  '  Sebamed ',
#  '  Nuggela & Sulé ',
#  '  Nuggela & Sulé ',
#  '  Avene ',
#  '  Avene ',
#  '  Triconatura ',
#  '  Xhekpon ',
#  '  Klorane ',
#  '  Isdin ',
#  '  Isdin ',
#  '  Isdin ']

# %%
response = requests.get(url).text
beautiful = BeautifulSoup(response,'html.parser')
soup = BeautifulSoup(response,)
productos = soup.find_all('h5',class_ = 'product-name')
productos3 = [elemento.text for elemento in productos]
productos3
# Out:
# ['  Nuxellence Sérum Noche Antiedad Detox ',
#  '  Crème Fraîche® de Beauté Mascarilla Facial... ',
#  '  Aquabella Loción Esencia Renovadora de... ',
#  '  Aquabella Gel Purificante Micro-exfoliante ',
#  '  Pigmentbio H2O Solución Micelar Iluminadora ',
#  '  Pigmentbio Limpiador Iluminador Foaming Cream ',
#  '  Pigmentbio Crema Hidratante Daily care SPF... ',
#  '  Pigmentbio C-Concentrate Sérum... ',
#  '  Nuxuriance Ultra Crema Rica Redensificante... ',
#  '  Merveillance Expert Contorno de Ojos ',
#  '  Merveillance Expert Crema Enriquecida... ',
#  '  Merveillance Expert Crema Lift-Firmeza ',
#  '  Sesgen 32 Crema Gel Activador Celular ',
#  '  Loción Corporal Enriquecida Pieles Secas y... ',
#  '  Sérum Fortalecedor Pestañas+ Voluminizador ',
#  '  Sérum Densificador Cejas+ Cepillo ',
#  '  A-Oxitive Serum Defensa Antioxidante ',
#  '  A-Oxitive Aqua Crema Alisadora ',
#  '  Gel Anticelulítico Reafirmante Reductor ',
#  '  Máscara de Colágeno Tensor ',
#  '  BB Contorno de Ojos Calmante ',
#  '  Acniben RX Repair Limpiador Facial... ',
#  '  Acniben RX Gel Crema Hidratante ',
#  '  Ureadin Crema Manos Reparadora ']

# %%
response = requests.get(url).text
beautiful = BeautifulSoup(response,'html.parser')
soup = BeautifulSoup(response,)
precio_productos = soup.find_all('span', class_='price product-price pull-left')
precio3 = [elemento.text for elemento in precio_productos]
precio3
# Out:
# ['    45,99 €  ',
#  '    16,99 €  ',
#  '    13,99 €  ',
#  '    11,99 €  ',
#  '    10,99 €  ',
#  '    11,99 €  ',
#  '    21,50 €  ',
#  '    24,50 €  ',
#  '    45,99 €  ',
#  '    32,75 €  ',
#  '    39,99 €  ',
#  '    39,99 €  ',
#  '    45,99 €  ',
#  '  Desde   26,99 €  ',
#  '    33,95 €  ',
#  '    33,95 €  ',
#  '    35,99 €  ',
#  '    31,90 €  ',
#  '    12,99 €  ',
#  '    17,99 €  ',
#  '    13,99 €  ',
#  '    15,95 €  ',
#  '    14,75 €  ',
#  '    10,50 €  ']

# %%
page3 = {'Marca': marcas3,
            'Nombre' : productos3,
            'Precio': precio3}
page3 = pd.DataFrame(page3, columns = ['Marca', 'Nombre', 'Precio'])
page3
# Out:
#                 Marca                                            Nombre  \
# 0               Nuxe             Nuxellence Sérum Noche Antiedad Detox
# 1               Nuxe     Crème Fraîche® de Beauté Mascarilla Facial...
# 2               Nuxe         Aquabella Loción Esencia Renovadora de...
# 3               Nuxe        Aquabella Gel Purificante Micro-exfoliante
# 4           Bioderma       Pigmentbio H2O Solución Micelar Iluminadora
# 5           Bioderma     Pigmentbio Limpiador Iluminador Foaming Cream
# 6           Bioderma     Pigmentbio Crema Hidratante Daily care SPF...
# 7           Bioderma                 Pigmentbio C-Concentrate Sérum...
# 8               Nuxe     Nuxuriance Ultra Crema Rica Redensificante...
# 9               Nuxe              Merveillance Expert Contorno de Ojos
# 10              Nuxe          Merveillance Expert Crema Enriquecida...
# 11              Nuxe            Merveillance Expert Crema Lift-Firmeza
# 12          Sesderma             Sesgen 32 Crema Gel Activador Celular
# 13           Sebamed     Loción Corporal Enriquecida Pieles Secas y...
# 14    Nuggela & Sulé        Sérum Fortalecedor Pestañas+ Voluminizador
# 15    Nuggela & Sulé                 Sérum Densificador Cejas+ Cepillo
# 16             Avene              A-Oxitive Serum Defensa Antioxidante
# 17             Avene                    A-Oxitive Aqua Crema Alisadora
# 18       Triconatura           Gel Anticelulítico Reafirmante Reductor
# 19           Xhekpon                        Máscara de Colágeno Tensor
# 20           Klorane                      BB Contorno de Ojos Calmante
# 21             Isdin             Acniben RX Repair Limpiador Facial...
# 22             Isdin                   Acniben RX Gel Crema Hidratante
# 23             Isdin                    Ureadin Crema Manos Reparadora
#
#                  Precio
# 0             45,99 €
# 1             16,99 €
# 2             13,99 €
# 3             11,99 €
# 4             10,99 €
# 5             11,99 €
# 6             21,50 €
# 7             24,50 €
# 8             45,99 €
# 9             32,75 €
# 10            39,99 €
# 11            39,99 €
# 12            45,99 €
# 13    Desde   26,99 €
# 14            33,95 €
# 15            33,95 €
# 16            35,99 €
# 17            31,90 €
# 18            12,99 €
# 19            17,99 €
# 20            13,99 €
# 21            15,95 €
# 22            14,75 €
# 23            10,50 €

# %% [markdown]
# ### Página 4

# %%
url = 'https://www.primor.eu/66-dermocosmetica?p=4'

# %%
response = requests.get(url).text
beautiful = BeautifulSoup(response,'html.parser')
soup = BeautifulSoup(response,)
marcas = soup.find_all('h4',class_ = 'product-manufacturer')
marcas4 = [elemento.text for elemento in marcas]
marcas4
# Out:
# ['  Isdin ',
#  '  Isdin ',
#  '  Elancyl ',
#  '  Remescar ',
#  '  Vichy ',
#  '  Ducray ',
#  '  Ducray ',
#  '  Vichy ',
#  '  Vichy ',
#  '  Vichy ',
#  '  Vichy ',
#  '  Ducray ',
#  '  A-Derma ',
#  '  Inibsa ',
#  '  Inibsa ',
#  '  Eucerin ',
#  '  Eucerin ',
#  '  Neutrogena ',
#  '  La Roche-Posay ',
#  '  La Roche-Posay ',
#  '  La Roche-Posay ',
#  '  La Roche-Posay ',
#  '  Deiters ',
#  '  Germinal ']

# %%
response = requests.get(url).text
beautiful = BeautifulSoup(response,'html.parser')
soup = BeautifulSoup(response,)
productos = soup.find_all('h5',class_ = 'product-name')
productos4 = [elemento.text for elemento in productos]
productos4
# Out:
# ['  Ureadin Pack Crema Antiarrugas + Contorno... ',
#  '  Acniben Limpiador Purificante ',
#  '  Tratamiento Anticelulítico ',
#  '  Sérum con Vitamina C y Ácido Hialurónico ',
#  '  Normaderm S.O.S ',
#  '  Exomega Set Leche Emoliente y Aceite... ',
#  '  Exoderma Set Crema Emoliente y Aceite... ',
#  '  Liftactiv Specialist Glyc-C Ampollas... ',
#  '  LiftActiv Specialist Péptido Ampollas... ',
#  '  Normaderm Gel Limpiador Purificante Intenso ',
#  '  Normaderm Tónico Purificante ',
#  '  Bálsamo Labial ',
#  '  Crema Hidratante Compensadora Phys-Ac ',
#  '  Leche Corporal Hidratante Dermatológica ',
#  '  Gel Corporal Dermatológico ',
#  '  Atopicontrol Crema Forte ',
#  '  Mascarilla Facial Intensiva Antiedad ',
#  '  Hydro Boost Limpiador Agua Micelar ',
#  '  Cicaplast Baume B5 ',
#  '  Lipikar Aceite de Ducha ',
#  '  Toleriane Ultra Desmaquillante Ojos Pieles... ',
#  '  Tolériane Ultra 8 Concentrado Hidratante... ',
#  '  Aceite de Rosa Mosqueta 100% Puro ',
#  '  Crema de Día Nutrición Celular Intensiva ']

# %%
response = requests.get(url).text
beautiful = BeautifulSoup(response,'html.parser')
soup = BeautifulSoup(response,)
precio_productos = soup.find_all('span', class_='price product-price pull-left')
precio4 = [elemento.text for elemento in precio_productos]
precio4
# Out:
# ['    20,99 €  ',
#  '    14,99 €  ',
#  '    30,99 €  ',
#  '    19,99 €  ',
#  '    16,99 €  ',
#  '    14,99 €  ',
#  '    14,99 €  ',
#  '  Desde   41,99 €  ',
#  '  Desde   41,99 €  ',
#  '  Desde   13,99 €  ',
#  '    9,95 €  ',
#  '    6,95 €  ',
#  '    11,99 €  ',
#  '    3,99 €  ',
#  '    3,25 €  ',
#  '    15,95 €  ',
#  '    7,50 €  ',
#  '    11,50 €  ',
#  '    11,99 €  ',
#  '    17,99 €  ',
#  '    17,99 €  ',
#  '    18,99 €  ',
#  '    9,50 €  ',
#  '    19,99 €  ']

# %%
page4 = {'Marca': marcas4,
            'Nombre' : productos4,
            'Precio': precio4}
page4 = pd.DataFrame(page4, columns = ['Marca', 'Nombre', 'Precio'])
page4
# Out:
#                 Marca                                            Nombre  \
# 0              Isdin      Ureadin Pack Crema Antiarrugas + Contorno...
# 1              Isdin                     Acniben Limpiador Purificante
# 2            Elancyl                        Tratamiento Anticelulítico
# 3           Remescar          Sérum con Vitamina C y Ácido Hialurónico
# 4              Vichy                                   Normaderm S.O.S
# 5             Ducray           Exomega Set Leche Emoliente y Aceite...
# 6             Ducray          Exoderma Set Crema Emoliente y Aceite...
# 7              Vichy           Liftactiv Specialist Glyc-C Ampollas...
# 8              Vichy          LiftActiv Specialist Péptido Ampollas...
# 9              Vichy       Normaderm Gel Limpiador Purificante Intenso
# 10             Vichy                      Normaderm Tónico Purificante
# 11            Ducray                                    Bálsamo Labial
# 12           A-Derma             Crema Hidratante Compensadora Phys-Ac
# 13            Inibsa           Leche Corporal Hidratante Dermatológica
# 14            Inibsa                        Gel Corporal Dermatológico
# 15           Eucerin                          Atopicontrol Crema Forte
# 16           Eucerin              Mascarilla Facial Intensiva Antiedad
# 17        Neutrogena                Hydro Boost Limpiador Agua Micelar
# 18    La Roche-Posay                                Cicaplast Baume B5
# 19    La Roche-Posay                           Lipikar Aceite de Ducha
# 20    La Roche-Posay     Toleriane Ultra Desmaquillante Ojos Pieles...
# 21    La Roche-Posay       Tolériane Ultra 8 Concentrado Hidratante...
# 22           Deiters                 Aceite de Rosa Mosqueta 100% Puro
# 23          Germinal          Crema de Día Nutrición Celular Intensiva
#
#                  Precio
# 0             20,99 €
# 1             14,99 €
# 2             30,99 €
# 3             19,99 €
# 4             16,99 €
# 5             14,99 €
# 6             14,99 €
# 7     Desde   41,99 €
# 8     Desde   41,99 €
# 9     Desde   13,99 €
# 10             9,95 €
# 11             6,95 €
# 12            11,99 €
# 13             3,99 €
# 14             3,25 €
# 15            15,95 €
# 16             7,50 €
# 17            11,50 €
# 18            11,99 €
# 19            17,99 €
# 20            17,99 €
# 21            18,99 €
# 22             9,50 €
# 23            19,99 €

# %% [markdown]
# ### Página 5

# %%
url = 'https://www.primor.eu/66-dermocosmetica?p=5'

# %%
response = requests.get(url).text
beautiful = BeautifulSoup(response,'html.parser')
soup = BeautifulSoup(response,)
marcas = soup.find_all('h4',class_ = 'product-manufacturer')
marcas5 = [elemento.text for elemento in marcas]
marcas5
# Out:
# ['  Germinal ',
#  '  Germinal ',
#  '  Germinal ',
#  '  Sesderma ',
#  '  Sesderma ',
#  '  La Roche-Posay ',
#  '  Avene ',
#  '  Nutriceutics ',
#  '  Cumlaude ',
#  '  Avene ',
#  '  La Roche-Posay ',
#  '  Vichy ',
#  '  Eucerin ',
#  '  Vichy ',
#  '  Vichy ',
#  '  Vichy ',
#  '  The Ordinary ',
#  '  A-Derma ',
#  '  Germinal ',
#  '  Remescar ',
#  '  Avene ',
#  '  Avene ',
#  '  Avene ',
#  '  Vichy ']

# %%
response = requests.get(url).text
beautiful = BeautifulSoup(response,'html.parser')
soup = BeautifulSoup(response,)
productos = soup.find_all('h5',class_ = 'product-name')
productos5 = [elemento.text for elemento in productos]
productos5
# Out:
# ['  Acción Profunda Ampollas Antioxidantes Noche ',
#  '  Acción Profunda Ampollas Antioxidantes... ',
#  '  Essencial Nutriplus Crema Antiedad de Noche ',
#  '  Sesretinal Young Gel Hidratante Plus ',
#  '  Crema Hidratante Acglicolic Classic SPF15 ',
#  '  Toleriane Sensitive Le Teint Creme Crema... ',
#  '  Neceser Couvrance Polvo Mosaico Bronceador... ',
#  '  Wrinkles Away Vitaminas Piel Joven ',
#  '  Regenerum Gel ',
#  '  Couvrance Polvos Iluminadores ',
#  '  Redermic Pure Vitamin C10 sérum ',
#  '  Mineral Blend Base de Maquillaje ',
#  '  DermoPure Oil Control Stick Corrector ',
#  '  Liftactiv Hyalu Mask ',
#  '  Liftactiv Collagen Specialist ',
#  '  Liftactiv Vitamina C Concentrado... ',
#  '  B Oil ',
#  '  Gel de Ducha Hidroprotector ',
#  '  Contorno de Ojos Bolsas y Ojeras ',
#  '  Párpados Caídos ',
#  '  Couvrance Polvos Mosaico Translúcidos ',
#  '  Hydrance Perfeccionadora del Tono Enriquecida ',
#  '  Hydrance Perfeccionadora del Tono Ligera ',
#  '  Dermablend Corrección 3D ']

# %%
response = requests.get(url).text
beautiful = BeautifulSoup(response,'html.parser')
soup = BeautifulSoup(response,)
precio_productos = soup.find_all('span', class_='price product-price pull-left')
precio5 = [elemento.text for elemento in precio_productos]
precio5
# Out:
# ['    27,50 €  ',
#  '    18,99 €  ',
#  '    26,50 €  ',
#  '    45,99 €  ',
#  '    36,99 €  ',
#  '    16,99 €  ',
#  '    35,99 €  ',
#  '    9,95 €  ',
#  '    11,99 €  ',
#  '    18,99 €  ',
#  '    39,99 €  ',
#  '  Desde   16,99 €  ',
#  '    12,99 €  ',
#  '    31,99 €  ',
#  '    29,75 €  ',
#  '    26,50 €  ',
#  '    9,20 €  ',
#  '  Desde   17,99 €  ',
#  '    19,99 €  ',
#  '    29,99 €  ',
#  '    18,99 €  ',
#  '    18,99 €  ',
#  '    18,99 €  ',
#  '  Desde   19,95 €  ']

# %%
page5 = {'Marca': marcas5,
            'Nombre' : productos5,
            'Precio': precio5}
page5 = pd.DataFrame(page5, columns = ['Marca', 'Nombre', 'Precio'])
page5
# Out:
#                 Marca                                            Nombre  \
# 0           Germinal      Acción Profunda Ampollas Antioxidantes Noche
# 1           Germinal         Acción Profunda Ampollas Antioxidantes...
# 2           Germinal       Essencial Nutriplus Crema Antiedad de Noche
# 3           Sesderma              Sesretinal Young Gel Hidratante Plus
# 4           Sesderma         Crema Hidratante Acglicolic Classic SPF15
# 5     La Roche-Posay       Toleriane Sensitive Le Teint Creme Crema...
# 6              Avene     Neceser Couvrance Polvo Mosaico Bronceador...
# 7       Nutriceutics                Wrinkles Away Vitaminas Piel Joven
# 8           Cumlaude                                     Regenerum Gel
# 9              Avene                     Couvrance Polvos Iluminadores
# 10    La Roche-Posay                   Redermic Pure Vitamin C10 sérum
# 11             Vichy                  Mineral Blend Base de Maquillaje
# 12           Eucerin             DermoPure Oil Control Stick Corrector
# 13             Vichy                              Liftactiv Hyalu Mask
# 14             Vichy                     Liftactiv Collagen Specialist
# 15             Vichy               Liftactiv Vitamina C Concentrado...
# 16      The Ordinary                                             B Oil
# 17           A-Derma                       Gel de Ducha Hidroprotector
# 18          Germinal                  Contorno de Ojos Bolsas y Ojeras
# 19          Remescar                                   Párpados Caídos
# 20             Avene             Couvrance Polvos Mosaico Translúcidos
# 21             Avene     Hydrance Perfeccionadora del Tono Enriquecida
# 22             Avene          Hydrance Perfeccionadora del Tono Ligera
# 23             Vichy                          Dermablend Corrección 3D
#
#                  Precio
# 0             27,50 €
# 1             18,99 €
# 2             26,50 €
# 3             45,99 €
# 4             36,99 €
# 5             16,99 €
# 6             35,99 €
# 7              9,95 €
# 8             11,99 €
# 9             18,99 €
# 10            39,99 €
# 11    Desde   16,99 €
# 12            12,99 €
# 13            31,99 €
# 14            29,75 €
# 15            26,50 €
# 16             9,20 €
# 17    Desde   17,99 €
# 18            19,99 €
# 19            29,99 €
# 20            18,99 €
# 21            18,99 €
# 22            18,99 €
# 23    Desde   19,95 €

# %% [markdown]
# ### Página 6

# %%
url = 'https://www.primor.eu/66-dermocosmetica?p=6'

# %%
response = requests.get(url).text
beautiful = BeautifulSoup(response,'html.parser')
soup = BeautifulSoup(response,)
marcas = soup.find_all('h4',class_ = 'product-manufacturer')
marcas6 = [elemento.text for elemento in marcas]
marcas6
# Out:
# ['  Vichy ',
#  '  Arganour ',
#  '  Avene ',
#  '  Avene ',
#  '  Avene ',
#  '  Roc ',
#  '  Grisi ',
#  '  Germinal ',
#  '  Sesderma ',
#  '  Sesderma ',
#  '  Vichy ',
#  '  La Roche-Posay ',
#  '  Sesderma ',
#  '  Sesderma ',
#  '  Sesderma ',
#  '  Sesderma ',
#  '  Sesderma ',
#  '  Sesderma ',
#  '  La Roche-Posay ',
#  '  Avene ',
#  '  Germinal ',
#  '  La Roche-Posay ',
#  '  La Roche-Posay ',
#  '  Vichy ']

# %%
response = requests.get(url).text
beautiful = BeautifulSoup(response,'html.parser')
soup = BeautifulSoup(response,)
productos = soup.find_all('h5',class_ = 'product-name')
productos6 = [elemento.text for elemento in productos]
productos6
# Out:
# ['  Normaderm Embellecedor Anti Imperfecciones ',
#  '  Aceite Puro de Semillas de Higo Chumbo Bio ',
#  '  Couvrance Maquillaje Fluido ',
#  '  Couvrance Crema Compacta Acabado Mate ',
#  '  Couvrance Crema Compacta Enriquecida ',
#  '  Pro Calm Crema Calmante Reconfortante ',
#  '  Leche de Burra Dermojabón ',
#  '  Ampollas Flash Acción Inmediata ',
#  '  Glicare Gel Contorno de Ojos Y Labios ',
#  '  Daeses Liposomal Serum ',
#  '  Liftactiv Flexilift Base de Maquillaje ',
#  '  Toleriane Ultra Contorno de Ojos ',
#  '  Daeses Crema Gel Reafirmante Facial ',
#  '  C-vit Radiance Fluido Luminoso ',
#  '  C-vit Liposomal Serum ',
#  '  C-Vit Crema Facial Hidratante ',
#  '  Acglicolic 20 Gel Hidratante ',
#  '  Acglicolic 20 Crema Gel Hidratante ',
#  '  Rosaliac Cc Cream ',
#  '  Compacto ',
#  '  Accion Inmediata Pieles Secas ',
#  '  Toleriane Fluido ',
#  '  Hydreane Bb ',
#  '  Dermablend Base de Maquillaje Correctora ']

# %%
response = requests.get(url).text
beautiful = BeautifulSoup(response,'html.parser')
soup = BeautifulSoup(response,)
precio_productos = soup.find_all('span', class_='price product-price pull-left')
precio6 = [elemento.text for elemento in precio_productos]
precio6
# Out:
# ['    16,99 €  ',
#  '    19,95 €  ',
#  '  Desde   15,99 €  ',
#  '    18,99 €  ',
#  '  Desde   18,99 €  ',
#  '    13,75 €  ',
#  '    3,95 €  ',
#  '    15,99 €  ',
#  '    19,99 €  ',
#  '    36,99 €  ',
#  '  Desde   19,95 €  ',
#  '    16,99 €  ',
#  '    36,99 €  ',
#  '    29,99 €  ',
#  '    29,99 €  ',
#  '    29,99 €  ',
#  '    36,99 €  ',
#  '    38,90 €  ',
#  '    17,99 €  ',
#  '  Desde   17,99 €  ',
#  '    10,99 €  ',
#  '  Desde   14,99 €  ',
#  '  Desde   12,99 €  ',
#  '    18,99 €  ']

# %%
page6 = {'Marca': marcas6,
            'Nombre' : productos6,
            'Precio': precio6}
page6 = pd.DataFrame(page6, columns = ['Marca', 'Nombre', 'Precio'])
page6
# Out:
#                 Marca                                         Nombre  \
# 0              Vichy     Normaderm Embellecedor Anti Imperfecciones
# 1           Arganour     Aceite Puro de Semillas de Higo Chumbo Bio
# 2              Avene                    Couvrance Maquillaje Fluido
# 3              Avene          Couvrance Crema Compacta Acabado Mate
# 4              Avene           Couvrance Crema Compacta Enriquecida
# 5                Roc          Pro Calm Crema Calmante Reconfortante
# 6              Grisi                      Leche de Burra Dermojabón
# 7           Germinal                Ampollas Flash Acción Inmediata
# 8           Sesderma          Glicare Gel Contorno de Ojos Y Labios
# 9           Sesderma                         Daeses Liposomal Serum
# 10             Vichy         Liftactiv Flexilift Base de Maquillaje
# 11    La Roche-Posay               Toleriane Ultra Contorno de Ojos
# 12          Sesderma            Daeses Crema Gel Reafirmante Facial
# 13          Sesderma                 C-vit Radiance Fluido Luminoso
# 14          Sesderma                          C-vit Liposomal Serum
# 15          Sesderma                  C-Vit Crema Facial Hidratante
# 16          Sesderma                   Acglicolic 20 Gel Hidratante
# 17          Sesderma             Acglicolic 20 Crema Gel Hidratante
# 18    La Roche-Posay                              Rosaliac Cc Cream
# 19             Avene                                       Compacto
# 20          Germinal                  Accion Inmediata Pieles Secas
# 21    La Roche-Posay                               Toleriane Fluido
# 22    La Roche-Posay                                    Hydreane Bb
# 23             Vichy       Dermablend Base de Maquillaje Correctora
#
#                  Precio
# 0             16,99 €
# 1             19,95 €
# 2     Desde   15,99 €
# 3             18,99 €
# 4     Desde   18,99 €
# 5             13,75 €
# 6              3,95 €
# 7             15,99 €
# 8             19,99 €
# 9             36,99 €
# 10    Desde   19,95 €
# 11            16,99 €
# 12            36,99 €
# 13            29,99 €
# 14            29,99 €
# 15            29,99 €
# 16            36,99 €
# 17            38,90 €
# 18            17,99 €
# 19    Desde   17,99 €
# 20            10,99 €
# 21    Desde   14,99 €
# 22    Desde   12,99 €
# 23            18,99 €

# %% [markdown]
# ### Página 7

# %%
url = 'https://www.primor.eu/66-dermocosmetica?p=7'

# %%
response = requests.get(url).text
beautiful = BeautifulSoup(response,'html.parser')
soup = BeautifulSoup(response,)
marcas = soup.find_all('h4',class_ = 'product-manufacturer')
marcas7 = [elemento.text for elemento in marcas]
marcas7
# Out:
# ['  Avene ', '  Xhekpon ', '  Doctor Hauschka ']

# %%
response = requests.get(url).text
beautiful = BeautifulSoup(response,'html.parser')
soup = BeautifulSoup(response,)
productos = soup.find_all('h5',class_ = 'product-name')
productos7 = [elemento.text for elemento in productos]
productos7
# Out:
# ['  Couvrance Polvos Bronceadores ',
#  '  Crema ',
#  '  Mascarilla Rejuvenecedora ']

# %%
response = requests.get(url).text
beautiful = BeautifulSoup(response,'html.parser')
soup = BeautifulSoup(response,)
precio_productos = soup.find_all('span', class_='price product-price pull-left')
precio7 = [elemento.text for elemento in precio_productos]
precio7
# Out:
# ['    18,99 €  ', '    4,95 €  ', '    27,99 €  ']

# %%
page7 = {'Marca': marcas7,
            'Nombre' : productos7,
            'Precio': precio7}
page7 = pd.DataFrame(page7, columns = ['Marca', 'Nombre', 'Precio'])
page7
# Out:
#                 Marca                            Nombre         Precio
# 0              Avene     Couvrance Polvos Bronceadores       18,99 €
# 1            Xhekpon                             Crema        4,95 €
# 2    Doctor Hauschka         Mascarilla Rejuvenecedora       27,99 €
